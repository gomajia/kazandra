# %%
#pip install --upgrade pycaret

# %%
from pycaret.time_series import TSForecastingExperiment

import pandas as pd
import numpy as np

import datetime
import random

import sys
import os

# %%
file_path = os.path.join('data','serie.csv')
df=pd.read_csv(file_path, low_memory=False)
df['time']=pd.to_datetime(df['time'])
df.set_index(keys='time',inplace=True)
df
# Out:
#                      id_incident_nunique
# time
# 2016-01-01 00:00:00                    1
# 2016-01-01 01:00:00                    2
# 2016-01-01 02:00:00                    4
# 2016-01-01 03:00:00                    3
# 2016-01-01 04:00:00                    6
# ...                                  ...
# 2023-05-17 12:00:00                   17
# 2023-05-17 13:00:00                   13
# 2023-05-17 14:00:00                    9
# 2023-05-17 15:00:00                    7
# 2023-05-17 16:00:00                    1
#
# [64649 rows x 1 columns]

# %%
forecast = TSForecastingExperiment()

# %%
estimator="lightgbm_cds_dt"
fh=24
verbose=False

# %%
forecast.setup(data=df,verbose=verbose)
forecast_mdl=forecast.create_model(**dict(estimator=f"{estimator}", verbose=verbose))
forecast_mdl=forecast.tune_model(**dict(estimator=forecast_mdl, verbose=verbose))
forecast_mdl=forecast.finalize_model(**dict(estimator=forecast_mdl))

# %%
df_tmp=forecast.predict_model(**dict(estimator=forecast_mdl, return_pred_int=False, fh=fh, round=0, verbose=verbose))
df_tmp
# Out:
#                   y_pred
# 2023-05-17 17:00    11.0
# 2023-05-17 18:00    17.0
# 2023-05-17 19:00    18.0
# 2023-05-17 20:00    18.0
# 2023-05-17 21:00    15.0
# 2023-05-17 22:00    14.0
# 2023-05-17 23:00    11.0
# 2023-05-18 00:00     8.0
# 2023-05-18 01:00     6.0
# 2023-05-18 02:00     4.0
# 2023-05-18 03:00     3.0
# 2023-05-18 04:00     1.0
# 2023-05-18 05:00     1.0
# 2023-05-18 06:00     5.0
# 2023-05-18 07:00    12.0
# 2023-05-18 08:00    16.0
# 2023-05-18 09:00    16.0
# 2023-05-18 10:00    16.0
# 2023-05-18 11:00    16.0
# 2023-05-18 12:00    19.0
# 2023-05-18 13:00    20.0
# 2023-05-18 14:00    23.0
# 2023-05-18 15:00    25.0
# 2023-05-18 16:00    25.0
